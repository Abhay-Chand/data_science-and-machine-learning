# %% [markdown]
# <a href="https://colab.research.google.com/github/Abhay-Chand/data_science-and-machine-learning/blob/main/new_pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
dic1 = {
    "name" :['abhay','garima','ajay','jyoti'],
    "marks":[35,34,36,35],
    "city":['tanakpur','champawat','aao','puri']
}

# %%
df = pd.DataFrame(dic1)
df
# Out:
#      name  marks       city
# 0   abhay     35   tanakpur
# 1  garima     34  champawat
# 2    ajay     36        aao
# 3   jyoti     35       puri

# %%
 df.to_csv('friends.csv')

# %% [markdown]
#  df.to_csv('friends.csv', index = False)
#
# *   List item
# *   List item

# %%
 df.to_csv('friends.csv', index = False)

# %%
df.head()
# Out:
#      name  marks       city
# 0   abhay     35   tanakpur
# 1  garima     34  champawat
# 2    ajay     36        aao
# 3   jyoti     35       puri

# %%
df.tail(3)
# Out:
#      name  marks       city
# 1  garima     34  champawat
# 2    ajay     36        aao
# 3   jyoti     35       puri

# %%
df.describe()
# Out:
#            marks
# count   4.000000
# mean   35.000000
# std     0.816497
# min    34.000000
# 25%    34.750000
# 50%    35.000000
# 75%    35.250000
# max    36.000000

# %%
olympic24 = pd.read_csv('olympics2024.csv')
olympic24
# Out:
#     Rank        Country Country Code  Gold  Silver  Bronze  Total
# 0      1  United States           US    40      44      42    126
# 1      2          China          CHN    40      27      24     91
# 2      3          Japan          JPN    20      12      13     45
# 3      4      Australia          AUS    18      19      16     53
# 4      5         France          FRA    16      26      22     64
# ..   ...            ...          ...   ...     ...     ...    ...
# 86    84           Peru          PER     0       0       1      1
# 87    84          Qatar          QAT     0       0       1      1
# 88    84      Singapore          SIN     0       0       1      1
# 89    84       Slovakia          SVK     0       0       1      1
# 90    84         Zambia          ZAM     0       0       1      1
#
# [91 rows x 7 columns]

# %%
olympic24.head(40)
# Out:
#     Rank         Country Country Code  Gold  Silver  Bronze  Total
# 0      1   United States           US    40      44      42    126
# 1      2           China          CHN    40      27      24     91
# 2      3           Japan          JPN    20      12      13     45
# 3      4       Australia          AUS    18      19      16     53
# 4      5          France          FRA    16      26      22     64
# 5      6     Netherlands          NED    15       7      12     34
# 6      7   Great Britain          GBG    14      22      29     65
# 7      8     South Korea          KOR    13       9      10     32
# 8      9           Italy          ITA    12      13      15     40
# 9     10         Germany          GER    12      13       8     33
# 10    11     New Zealand           NZ    10       7       3     20
# 11    12          Canada          CAN     9       7      11     27
# 12    13      Uzbekistan          UZB     8       2       3     13
# ...

# %%
olympic24['Gold'][0] = 100
# Out:
# <ipython-input-47-b376683cc0a4>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   olympic24['Gold'][0] = 100

# %%
olympic24['Gold'][24] = 100
olympic24.to_csv('olympic24.csv')
# Out:
# <ipython-input-51-869a032e23fe>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   olympic24['Gold'][24] = 100

# %%
olympic24.describe()
# Out:
#             Rank       Gold     Silver     Bronze       Total
# count  91.000000   91.00000  91.000000  91.000000   91.000000
# mean   45.307692    5.32967   3.593407   4.219780   11.417582
# std    25.652244   15.41504   6.770816   6.558798   19.702829
# min     1.000000    0.00000   0.000000   0.000000    1.000000
# 25%    23.500000    0.00000   0.000000   1.000000    2.000000
# 50%    44.000000    1.00000   1.000000   2.000000    5.000000
# 75%    68.000000    3.00000   3.000000   5.000000    9.000000
# max    84.000000  100.00000  44.000000  42.000000  126.000000

# %% [markdown]
# **NEW FILE**

# %%
newdf = pd.DataFrame(np.random.rand(334,5) , index = np.arange(334))
type(newdf)
newdf
# Out:
#             0         1         2         3         4
# 0    0.650265  0.770739  0.835295  0.899433  0.507756
# 1    0.736938  0.053917  0.409837  0.236840  0.492652
# 2    0.087006  0.664373  0.637313  0.947359  0.222194
# 3    0.161860  0.460831  0.002746  0.448620  0.474957
# 4    0.590456  0.624166  0.498611  0.392557  0.202782
# ..        ...       ...       ...       ...       ...
# 329  0.912267  0.448412  0.371205  0.549277  0.906690
# 330  0.508836  0.891376  0.874014  0.492968  0.191894
# 331  0.500943  0.052208  0.288532  0.897933  0.019238
# 332  0.426428  0.276659  0.323638  0.557825  0.356680
# 333  0.167649  0.375387  0.129175  0.644030  0.560966
#
# [334 rows x 5 columns]

# %%
newdf.describe()
# Out:
#                 0           1           2           3           4
# count  334.000000  334.000000  334.000000  334.000000  334.000000
# mean     0